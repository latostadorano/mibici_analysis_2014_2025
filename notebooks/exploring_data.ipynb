# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importamos datos de paseos
df_paseos = pd.read_csv("/Users/pablo/Desktop/temp/DA/miBici/mibici_2025/data/raw/mibici_2014-2024.csv", nrows = 50000)
df_paseos.head()
# Out:
#    Unnamed: 0   Trip_Id  User_Id Sex  Birth_year           Trip_start  \
# 0           0  32244893  1470734   M        1981  2024-01-31 23:59:33
# 1           1  32244892  2731702   M        1994  2024-01-31 23:59:06
# 2           2  32244891  1431452   M        2001  2024-01-31 23:58:48
# 3           3  32244890  2312602   F        2003  2024-01-31 23:58:44
# 4           4  32244889  2266427   M        1999  2024-01-31 23:58:44
#
#               Trip_end  Origin_Id  Destination_Id  Age         Duration
# 0  2024-02-01 00:11:15         24              86   43  0 days 00:11:42
# 1  2024-02-01 00:10:49         48             279   30  0 days 00:11:43
# 2  2024-02-01 00:01:42        273             383   23  0 days 00:02:54
# 3  2024-02-01 00:01:58        273             383   21  0 days 00:03:14
# 4  2024-02-01 00:01:39        273             383   25  0 days 00:02:55

# %%
# Importamos datos de estaciones
estaciones = pd.read_csv('/Users/pablo/Desktop/temp/DA/miBici/mibici_2025/data/raw/nomenclatura_2025_10.csv', encoding="latin1")
estaciones.head()
# Out:
#    id                                           name     obcn  \
# 0   2  (GDL-001) C. Epigmenio Glez./ Av. 16 de Sept.  GDL-001
# 1   3     (GDL-002) C. Colonias  / Av.  Niños héroes  GDL-002
# 2   4          (GDL-003) C. Vidrio / Av. Chapultepec  GDL-003
# 3   5           (GDL-004) C. Ghilardi /C. Miraflores  GDL-004
# 4   6  (GDL-005) C. San Diego /Calzada Independencia  GDL-005
#
#            location   latitude   longitude      status
# 0  POLÍGONO CENTRAL  20.666378 -103.348820  IN_SERVICE
# 1  POLÍGONO CENTRAL  20.667228 -103.366000  IN_SERVICE
# 2  POLÍGONO CENTRAL  20.667690 -103.368252  IN_SERVICE
# 3  POLÍGONO CENTRAL  20.691847 -103.362549  IN_SERVICE
# 4  POLÍGONO CENTRAL  20.681158 -103.339363  IN_SERVICE

# %%
df_paseos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      50000 non-null  int64
#  1   Trip_Id         50000 non-null  int64
#  2   User_Id         50000 non-null  int64
#  3   Sex             50000 non-null  object
#  4   Birth_year      50000 non-null  int64
#  5   Trip_start      50000 non-null  object
#  6   Trip_end        50000 non-null  object
#  7   Origin_Id       50000 non-null  int64
#  8   Destination_Id  50000 non-null  int64
#  9   Age             50000 non-null  int64
#  10  Duration        50000 non-null  object
# dtypes: int64(7), object(4)
# memory usage: 4.2+ MB

# %%
df_paseos[['Birth_year', 'Age']].describe()
# Out:
#          Birth_year           Age
# count  50000.000000  50000.000000
# mean    1989.567860     34.432140
# std       10.809846     10.809846
# min     1920.000000     17.000000
# 25%     1984.000000     27.000000
# 50%     1992.000000     32.000000
# 75%     1997.000000     40.000000
# max     2007.000000    104.000000

# %%
# Eliminamos columna unnamed
df_paseos.drop('Unnamed: 0', axis=1, inplace=True)

# %%
# Cambiamos columnas a bajas
df_paseos.columns = df_paseos.columns.str.lower().str.replace(' ', '_').str.strip()

# Convertimos trip_end y trip_start a datetime
df_paseos.trip_end = pd.to_datetime(df_paseos.trip_end, errors=('coerce'))
df_paseos.trip_start = pd.to_datetime(df_paseos.trip_start, errors=('coerce'))

# Sacamos fecha del viaje, mes y año
df_paseos['date'] = df_paseos.trip_start.dt.to_period('M')

# Agregamos columna de duración del viaje, en minutos
df_paseos['duration_m'] = ((df_paseos.trip_end - df_paseos.trip_start).dt.total_seconds() / 60).round().astype(int)

df_paseos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   trip_id         50000 non-null  int64
#  1   user_id         50000 non-null  int64
#  2   sex             50000 non-null  object
#  3   birth_year      50000 non-null  int64
#  4   trip_start      50000 non-null  datetime64[ns]
#  5   trip_end        50000 non-null  datetime64[ns]
#  6   origin_id       50000 non-null  int64
#  7   destination_id  50000 non-null  int64
#  8   age             50000 non-null  int64
#  9   duration        50000 non-null  object
#  10  date            50000 non-null  period[M]
#  11  duration_m      50000 non-null  int64
# dtypes: datetime64[ns](2), int64(7), object(2), period[M](1)
# memory usage: 4.6+ MB

# %%
df_paseos.head()
# Out:
#     trip_id  user_id sex  birth_year          trip_start            trip_end  \
# 0  32244893  1470734   M        1981 2024-01-31 23:59:33 2024-02-01 00:11:15
# 1  32244892  2731702   M        1994 2024-01-31 23:59:06 2024-02-01 00:10:49
# 2  32244891  1431452   M        2001 2024-01-31 23:58:48 2024-02-01 00:01:42
# 3  32244890  2312602   F        2003 2024-01-31 23:58:44 2024-02-01 00:01:58
# 4  32244889  2266427   M        1999 2024-01-31 23:58:44 2024-02-01 00:01:39
#
#    origin_id  destination_id  age         duration     date  duration_m
# 0         24              86   43  0 days 00:11:42  2024-01          12
# 1         48             279   30  0 days 00:11:43  2024-01          12
# 2        273             383   23  0 days 00:02:54  2024-01           3
# 3        273             383   21  0 days 00:03:14  2024-01           3
# 4        273             383   25  0 days 00:02:55  2024-01           3

# %%
estaciones.head()
# Out:
#    id                                           name     obcn  \
# 0   2  (GDL-001) C. Epigmenio Glez./ Av. 16 de Sept.  GDL-001
# 1   3     (GDL-002) C. Colonias  / Av.  Niños héroes  GDL-002
# 2   4          (GDL-003) C. Vidrio / Av. Chapultepec  GDL-003
# 3   5           (GDL-004) C. Ghilardi /C. Miraflores  GDL-004
# 4   6  (GDL-005) C. San Diego /Calzada Independencia  GDL-005
#
#            location   latitude   longitude      status
# 0  POLÍGONO CENTRAL  20.666378 -103.348820  IN_SERVICE
# 1  POLÍGONO CENTRAL  20.667228 -103.366000  IN_SERVICE
# 2  POLÍGONO CENTRAL  20.667690 -103.368252  IN_SERVICE
# 3  POLÍGONO CENTRAL  20.691847 -103.362549  IN_SERVICE
# 4  POLÍGONO CENTRAL  20.681158 -103.339363  IN_SERVICE

# %%
estaciones.location.value_counts()
# Out:
# location
# POLÍGONO CENTRAL     287
# TLQ-CORREDORATLAS     49
# ZAPOPAN CENTRO        47
# Name: count, dtype: int64

# %%
estaciones.status.value_counts()
# Out:
# status
# IN_SERVICE        366
# NOT_IN_SERVICE     17
# Name: count, dtype: int64

# %%
# limpiamos columna name
estaciones = estaciones.rename(columns={'obcn': 'station_code'})
estaciones["name"] = estaciones["name"].str.replace(r"\([^)]*\)\s*", "", regex=True)
estaciones.head()
# Out:
#    id                                 name station_code          location  \
# 0   2  C. Epigmenio Glez./ Av. 16 de Sept.      GDL-001  POLÍGONO CENTRAL
# 1   3     C. Colonias  / Av.  Niños héroes      GDL-002  POLÍGONO CENTRAL
# 2   4          C. Vidrio / Av. Chapultepec      GDL-003  POLÍGONO CENTRAL
# 3   5           C. Ghilardi /C. Miraflores      GDL-004  POLÍGONO CENTRAL
# 4   6  C. San Diego /Calzada Independencia      GDL-005  POLÍGONO CENTRAL
#
#     latitude   longitude      status
# 0  20.666378 -103.348820  IN_SERVICE
# 1  20.667228 -103.366000  IN_SERVICE
# 2  20.667690 -103.368252  IN_SERVICE
# 3  20.691847 -103.362549  IN_SERVICE
# 4  20.681158 -103.339363  IN_SERVICE

# %%
# Creamos dataset de origins

df_origin = estaciones[['id', 'station_code']]
df_origin = df_origin.rename(columns= {'id': 'origin_id', 'station_code': 'station_code_origin'})
df_origin.head()
# Out:
#    origin_id station_code_origin
# 0          2             GDL-001
# 1          3             GDL-002
# 2          4             GDL-003
# 3          5             GDL-004
# 4          6             GDL-005

# %%
# Dataset destinations

df_destination = estaciones[['id', 'station_code']]
df_destination = df_destination.rename(columns={'id': 'destination_id', 'station_code': 'station_code_destination'})
df_destination.head()
# Out:
#    destination_id station_code_destination
# 0               2                  GDL-001
# 1               3                  GDL-002
# 2               4                  GDL-003
# 3               5                  GDL-004
# 4               6                  GDL-005

# %%
# Juntamos todas las tablas

df = pd.merge(df_paseos, df_origin, on='origin_id')
df = pd.merge(df, df_destination, on = 'destination_id')

df.head()
# Out:
#     trip_id  user_id sex  birth_year          trip_start            trip_end  \
# 0  32244893  1470734   M        1981 2024-01-31 23:59:33 2024-02-01 00:11:15
# 1  32244892  2731702   M        1994 2024-01-31 23:59:06 2024-02-01 00:10:49
# 2  32244891  1431452   M        2001 2024-01-31 23:58:48 2024-02-01 00:01:42
# 3  32244890  2312602   F        2003 2024-01-31 23:58:44 2024-02-01 00:01:58
# 4  32244889  2266427   M        1999 2024-01-31 23:58:44 2024-02-01 00:01:39
#
#    origin_id  destination_id  age         duration     date  duration_m  \
# 0         24              86   43  0 days 00:11:42  2024-01          12
# 1         48             279   30  0 days 00:11:43  2024-01          12
# 2        273             383   23  0 days 00:02:54  2024-01           3
# 3        273             383   21  0 days 00:03:14  2024-01           3
# 4        273             383   25  0 days 00:02:55  2024-01           3
#
#   station_code_origin station_code_destination
# 0             GDL-022                  GDL-084
# 1             GDL-046                  GDL-206
# 2             GDL-200                  GDL-240
# 3             GDL-200                  GDL-240
# 4             GDL-200                  GDL-240
